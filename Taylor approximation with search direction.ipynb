# %%
using Plots

f(α) = α^3-5*(α)*(2-α)+6*(2-α)^2
f1(α) = 24-34α
f2(α) = 24-34α+11α^2

dom = range(0, 1, length=10000)
y = [ f.(dom) f1.(dom) f2.(dom) ]

plot(dom, y, label = ["f(x+ap)" "1st order" "2nd order"],fmt = :png)
